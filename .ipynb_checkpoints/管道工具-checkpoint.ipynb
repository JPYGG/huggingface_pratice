# %% [markdown]
# ### 1 常见nlp任务演示

# %% [markdown]
# #### 1.1 文本分类

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline
import torch
print(torch.__version__)
# import os
# os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"
# Out:
# 2.11.0+cu128

# %%
classifier = pipeline('sentiment-analysis')
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]

# %%
classifier('I hate you')
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9991129040718079}]

# %%
classifier('I love you')
# Out:
# [{'label': 'POSITIVE', 'score': 0.9998656511306763}]

# %% [markdown]
# #### 1.2 阅读理解

# %%
# 1. 显式指定模型
model_name = "distilbert-base-cased-distilled-squad"

# 2. 直接加载模型和分词器
model = AutoModelForQuestionAnswering.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# 3. 把加载好的对象传给 pipeline
# 注意：这里我们避开了只传字符串，直接传对象
question_answerer = pipeline(task="question-answering", model=model, tokenizer=tokenizer)

# 4. 测试运行
result = question_answerer(
    question="What is the problem?",
    context="The problem is a KeyError in the transformers pipeline registration."
)
print(result)
# Out:
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 10
#       6 tokenizer = AutoTokenizer.from_pretrained(model_name)
#       8 # 3. 把加载好的对象传给 pipeline
#       9 # 注意：这里我们避开了只传字符串，直接传对象
# ---> 10 question_answerer = pipeline(task="question-answering", model=model, tokenizer=tokenizer)
#      12 # 4. 测试运行
#      13 result = question_answerer(
#      14     question="What is the problem?",
#      15     context="The problem is a KeyError in the transformers pipeline registration."
#      16 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:742, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     735         pipeline_class = get_class_from_dynamic_module(
#     736             class_ref,
#     737             model,
#     738             code_revision=code_revision,
#     739             **hub_kwargs,
#     740         )
#     741 else:
# --> 742     normalized_task, targeted_task, task_options = check_task(task)
#     743     if pipeline_class is None:
#     744         pipeline_class = targeted_task["impl"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:355, in check_task(task)
#     319 def check_task(task: str) -> tuple[str, dict, Any]:
#     320     """
#     321     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     322     default models if they exist.
#    (...)    353
#     354     """
# --> 355     return PIPELINE_REGISTRY.check_task(task)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1338, in PipelineRegistry.check_task(self, task)
#    1335     targeted_task = self.supported_tasks[task]
#    1336     return task, targeted_task, None
# -> 1338 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task question-answering, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
question_answerer = pipeline('text-generation')
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
context = r"""
Extractive Question Answering is the task of extracting an answer from a text given a question. An example of a 
question answering dataset is the SQuAD dataset, which is entirely based on that task. If you would like to fine-tune 
a model on a SQuAD task, you may leverage the examples/pytorch/question-answering/run_squad.py script.
"""

# %%
question_answerer(
    question="What is extractive question answering?",
    context=context
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 question_answerer(
#       2     question="What is extractive question answering?",
#       3     context=context
#       4 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\feature_extraction.py:88, in FeatureExtractionPipeline.__call__(self, *args, **kwargs)
#      78 def __call__(self, *args: str | list[str], **kwargs: Any) -> Any | list[Any]:
#      79     """
#      80     Extract the features of the input(s) text.
#      81
#    (...)     86         A nested list of `float`: The features computed by the model.
#      87     """
# ---> 88     return super().__call__(*args, **kwargs)
#
# TypeError: Pipeline.__call__() missing 1 required positional argument: 'inputs'

# %% [markdown]
# #### 1.3 完型填空

# %%
sentence = 'HuggingFace is creating a <mask> that the community uses to solve NLP tasks.'

# %%
unmasker = pipeline('fill-mask')
# Out:
# [transformers] No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/106 [00:00<?, ?it/s]
# [transformers] RobertaForMaskedLM LOAD REPORT from: distilbert/distilroberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
unmasker(sentence)
# Out:
# [{'score': 0.17927570641040802,
#   'token': 3944,
#   'token_str': ' tool',
#   'sequence': 'HuggingFace is creating a tool that the community uses to solve NLP tasks.'},
#  {'score': 0.11349396407604218,
#   'token': 7208,
#   'token_str': ' framework',
#   'sequence': 'HuggingFace is creating a framework that the community uses to solve NLP tasks.'},
#  {'score': 0.05243537575006485,
#   'token': 5560,
#   'token_str': ' library',
#   'sequence': 'HuggingFace is creating a library that the community uses to solve NLP tasks.'},
#  {'score': 0.03493531793355942,
#   'token': 8503,
#   'token_str': ' database',
#   'sequence': 'HuggingFace is creating a database that the community uses to solve NLP tasks.'},
#  {'score': 0.028602436184883118,
#   'token': 17715,
#   'token_str': ' prototype',
#   'sequence': 'HuggingFace is creating a prototype that the community uses to solve NLP tasks.'}]

# %% [markdown]
# #### 1.4 文本生成

# %%
text_generator = pipeline('text-generation')
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 text_generator = pipeline('text-generation')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:993, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     990 if processor is not None:
#     991     kwargs["processor"] = processor
# --> 993 return pipeline_class(model=model, task=task, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\text_generation.py:100, in TextGenerationPipeline.__init__(self, *args, **kwargs)
#      99 def __init__(self, *args, **kwargs):
# --> 100     super().__init__(*args, **kwargs)
#     101     self.check_model_type(MODEL_FOR_CAUSAL_LM_MAPPING_NAMES)
#     102     # Decoder-only models require left-padding for correct batched generation.
#     103     # Only override when there is no feature_extractor, to avoid padding_side conflicts
#     104     # (e.g., WhisperForCausalLM has a feature_extractor that pads on the right).
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\base.py:854, in Pipeline.__init__(self, model, tokenizer, feature_extractor, image_processor, processor, task, device, binary_output, **kwargs)
#     848 # We shouldn't call `model.to()` for models loaded with accelerate as well as the case that model is already on device
#     849 if (
#     850     self.model.device != self.device
#     851     and not (isinstance(self.device, int) and self.device < 0)
#     852     and hf_device_map is None
#     853 ):
# --> 854     self.model.to(self.device)
#     856 # If it's a generation pipeline and the model can generate:
#     857 # 1 - create a local generation config. This is done to avoid side-effects on the model as we apply local
#     858 # tweaks to the generation config.
#     859 # 2 - load the assistant model if it is passed.
#     860 if self._pipeline_calls_generate and self.model.can_generate():
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\modeling_utils.py:3620, in PreTrainedModel.to(self, *args, **kwargs)
#    3615     if dtype_present_in_args:
#    3616         raise ValueError(
#    3617             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    3618             " `dtype` by passing the correct `dtype` argument."
#    3619         )
# -> 3620 return super().to(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1384, in Module.to(self, *args, **kwargs)
#    1381         else:
#    1382             raise
# -> 1384 return self._apply(convert)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
#     [... skipping similar frames: Module._apply at line 934 (2 times)]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:934, in Module._apply(self, fn, recurse)
#     932 if recurse:
#     933     for module in self.children():
# --> 934         module._apply(fn)
#     936 from torch._subclasses.fake_tensor import FakeTensor
#     938 def compute_should_use_set_data(tensor, tensor_applied) -> bool:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:965, in Module._apply(self, fn, recurse)
#     961 # Tensors stored in modules are graph leaves, and we don't want to
#     962 # track autograd history of `param_applied`, so we have to use
#     963 # `with torch.no_grad():`
#     964 with torch.no_grad():
# --> 965     param_applied = fn(param)
#     966 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     968 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File C:\ProgramData\anaconda3\Lib\site-packages\torch\nn\modules\module.py:1370, in Module.to.<locals>.convert(t)
#    1363     if convert_to_format is not None and t.dim() in (4, 5):
#    1364         return t.to(
#    1365             device,
#    1366             dtype if t.is_floating_point() or t.is_complex() else None,
#    1367             non_blocking,
#    1368             memory_format=convert_to_format,
#    1369         )
# -> 1370     return t.to(
#    1371         device,
#    1372         dtype if t.is_floating_point() or t.is_complex() else None,
#    1373         non_blocking,
#    1374     )
#    1375 except NotImplementedError as e:
#    1376     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 3.46 GiB is allocated by PyTorch, and 1.84 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
text_generator("As far as I am concerned, I will", 
              max_length=50,
              do_sample=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 text_generator("As far as I am concerned, I will",
#       2               max_length=50,
#       3               do_sample=False)
#
# NameError: name 'text_generator' is not defined

# %% [markdown]
# #### 1.5 命名实体识别

# %%
sequence = """Hugging face Inc. is a company based in New York City. Its headquarters are in DUMBO, therefore 
very close to the Manhattan Bridge which is visible from the window."""

# %%
ner_pipe = pipeline('ner')
# Out:
# [transformers] No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# [transformers] BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]

# %%
for entity in ner_pipe(sequence):
    print(entity)
# Out:
# {'entity': 'I-ORG', 'score': np.float32(0.99739873), 'index': 1, 'word': 'Hu', 'start': 0, 'end': 2}
# {'entity': 'I-ORG', 'score': np.float32(0.8361964), 'index': 2, 'word': '##gging', 'start': 2, 'end': 7}
# {'entity': 'I-ORG', 'score': np.float32(0.98196316), 'index': 3, 'word': 'face', 'start': 8, 'end': 12}
# {'entity': 'I-ORG', 'score': np.float32(0.9994504), 'index': 4, 'word': 'Inc', 'start': 13, 'end': 16}
# {'entity': 'I-LOC', 'score': np.float32(0.9994265), 'index': 11, 'word': 'New', 'start': 40, 'end': 43}
# {'entity': 'I-LOC', 'score': np.float32(0.9993144), 'index': 12, 'word': 'York', 'start': 44, 'end': 48}
# {'entity': 'I-LOC', 'score': np.float32(0.9993813), 'index': 13, 'word': 'City', 'start': 49, 'end': 53}
# {'entity': 'I-LOC', 'score': np.float32(0.9854054), 'index': 19, 'word': 'D', 'start': 79, 'end': 80}
# {'entity': 'I-LOC', 'score': np.float32(0.9548832), 'index': 20, 'word': '##UM', 'start': 80, 'end': 82}
# {'entity': 'I-LOC', 'score': np.float32(0.93450785), 'index': 21, 'word': '##BO', 'start': 82, 'end': 84}
# {'entity': 'I-LOC', 'score': np.float32(0.97838676), 'index': 28, 'word': 'Manhattan', 'start': 115, 'end': 124}
# {'entity': 'I-LOC', 'score': np.float32(0.9917589), 'index': 29, 'word': 'Bridge', 'start': 125, 'end': 131}

# %% [markdown]
# #### 1.6文本摘要

# %%
ARTICLE = """New York
CNN
 — 
When Liana Barrientos was 23 years old, she got married in Westchester County, New York.

A year later, she got married again in Westchester County, but to a different man and without divorcing her first husband. Only 18 days after that marriage, she got hitched yet again.

Then, Barrientos declared “I do” five more times, sometimes only within two weeks of each other.

In 2010, she married once more, this time in the Bronx. In an application for a marriage license, she stated it was her “first and only” marriage.

Liana Barrientos
Bronx County District Attorney's Office
Barrientos, now 39, is facing two criminal counts of “offering a false instrument for filing in the first degree,” referring to her false statements on the 2010 marriage license application, according to court documents. Prosecutors said the marriages were part of an immigration scam.

On Friday, she pleaded not guilty at State Supreme Court in the Bronx, according to her attorney, Christopher Wright, who declined to comment further.

After leaving court, Barrientos was arrested and charged with theft of service and criminal trespass for allegedly sneaking into the New York subway through an emergency exit, said Detective Annette Markowski, a police spokeswoman.

In total, Barrientos has been married 10 times, with nine of her marriages occurring between 1999 and 2002. All occurred either in Westchester County, Long Island, New Jersey or the Bronx.

She is believed to still be married to four men, and at one time, she was married to eight men at once, prosecutors say.

Prosecutors said the immigration scam involved some of her husbands, who filed for permanent residence status shortly after the marriages. Any divorces happened only after such filings were approved. It was unclear whether any of the men will be prosecuted.

The case was referred to the Bronx District Attorney’s Office by Immigration and Customs Enforcement and the Department of Homeland Security’s Investigation Division. Seven of the men are from so-called “red-flagged” countries, including Egypt, Turkey, Georgia, Pakistan and Mali.

Her eighth husband, Rashid Rajput, was deported in 2006 to his native Pakistan after an investigation by the Joint Terrorism Task Force.

If convicted, Barrientos faces up to four years in prison. Her next court appearance is scheduled for May 18."""

# %% [markdown]
# summarizer = pipeline('summarization')

# %%
summarizer(ARTICLE, max_length=130, min_length=30, do_sample=False)

# %% [markdown]
# #### 1.7翻译

# %%
translator = pipeline('translation_en_to_de')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 translator = pipeline('translation_en_to_de')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:742, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     735         pipeline_class = get_class_from_dynamic_module(
#     736             class_ref,
#     737             model,
#     738             code_revision=code_revision,
#     739             **hub_kwargs,
#     740         )
#     741 else:
# --> 742     normalized_task, targeted_task, task_options = check_task(task)
#     743     if pipeline_class is None:
#     744         pipeline_class = targeted_task["impl"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:355, in check_task(task)
#     319 def check_task(task: str) -> tuple[str, dict, Any]:
#     320     """
#     321     Checks an incoming task string, to validate it's correct and return the default Pipeline and Model classes, and
#     322     default models if they exist.
#    (...)    353
#     354     """
# --> 355     return PIPELINE_REGISTRY.check_task(task)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\pipelines\base.py:1338, in PipelineRegistry.check_task(self, task)
#    1335     targeted_task = self.supported_tasks[task]
#    1336     return task, targeted_task, None
# -> 1338 raise KeyError(f"Unknown task {task}, available tasks are {self.get_supported_tasks()}")
#
# KeyError: "Unknown task translation_en_to_de, available tasks are ['any-to-any', 'audio-classification', 'automatic-speech-recognition', 'depth-estimation', 'document-question-answering', 'feature-extraction', 'fill-mask', 'image-classification', 'image-feature-extraction', 'image-segmentation', 'image-text-to-text', 'keypoint-matching', 'mask-generation', 'ner', 'object-detection', 'sentiment-analysis', 'table-question-answering', 'text-classification', 'text-generation', 'text-to-audio', 'text-to-speech', 'token-classification', 'video-classification', 'zero-shot-audio-classification', 'zero-shot-classification', 'zero-shot-image-classification', 'zero-shot-object-detection']"

# %%
sentence = 'Huggine Face is a technology company based in New York and Paris'

# %%
translator(sentence, max_length=400)

# %% [markdown]
# ### 替换模型执行任务

# %%
# 如果默认的pipeline任务模型不满足要求, 可以自己指定想要使用的模型. 
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.1-cp313-cp313-win_amd64.whl.metadata (10 kB)
# Downloading sentencepiece-0.2.1-cp313-cp313-win_amd64.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 2.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 0.8/1.1 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 1.2 MB/s  0:00:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.1

# %%
sentence = '我叫萨拉, 我住在伦敦'

# %%
translator = pipeline(task='translation_zh_to_en',
        model=model,
        tokenizer=tokenizer)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 translator = pipeline(task='translation_zh_to_en',
# ----> 2         model=model,
#       3         tokenizer=tokenizer)
#
# NameError: name 'model' is not defined

# %%
translator(sentence, max_length=20)

# %%
# 英翻译 中
tokenizer = AutoTokenizer.from_pretrained('Helsinki-NLP/opus-mt-en-zh')
model = AutoModelForSeq2SeqLM.from_pretrained('Helsinki-NLP/opus-mt-en-zh')
translator = pipeline(task='translation_en_to_zh',
        model=model,
        tokenizer=tokenizer)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/44.0 [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 # 英翻译 中
# ----> 2 tokenizer = AutoTokenizer.from_pretrained('Helsinki-NLP/opus-mt-en-zh')
#       3 model = AutoModelForSeq2SeqLM.from_pretrained('Helsinki-NLP/opus-mt-en-zh')
#       4 translator = pipeline(task='translation_en_to_zh',
#       5         model=model,
#       6         tokenizer=tokenizer)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\transformers\models\auto\tokenization_auto.py:839, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     836         tokenizer_class = TokenizersBackend
#     837     return tokenizer_class.from_pretrained(pretrained_model_name_or_path, *inputs, **kwargs)
# --> 839 raise ValueError(
#     840     f"Unrecognized configuration class {config.__class__} to build an AutoTokenizer.\n"
#     841     f"Model type should be one of {', '.join(c.__name__ for c in TOKENIZER_MAPPING)}."
#     842 )
#
# ValueError: Unrecognized configuration class <class 'transformers.models.marian.configuration_marian.MarianConfig'> to build an AutoTokenizer.
# Model type should be one of GPT2Config, Aimv2Config, AlbertConfig, AlignConfig, AudioFlamingo3Config, AyaVisionConfig, BarkConfig, BartConfig, BertConfig, BertGenerationConfig, BigBirdConfig, BigBirdPegasusConfig, BioGptConfig, BlenderbotConfig, BlenderbotSmallConfig, BlipConfig, Blip2Config, BridgeTowerConfig, BrosConfig, CamembertConfig, CanineConfig, ChameleonConfig, ChineseCLIPConfig, ClapConfig, CLIPConfig, CLIPSegConfig, ClvpConfig, CodeGenConfig, CohereConfig, Cohere2Config, CohereAsrConfig, ColQwen2Config, ConvBertConfig, CpmAntConfig, CTRLConfig, Data2VecAudioConfig, Data2VecTextConfig, DbrxConfig, DebertaConfig, DebertaV2Config, DeepseekV2Config, DeepseekV3Config, DeepseekVLConfig, DeepseekVLHybridConfig, DiaConfig, DistilBertConfig, DPRConfig, ElectraConfig, Emu3Config, ErnieConfig, EsmConfig, FalconMambaConfig, FastSpeech2ConformerConfig, FlaubertConfig, FlavaConfig, FlexOlmoConfig, Florence2Config, FNetConfig, FSMTConfig, FunnelConfig, FuyuConfig, GemmaConfig, Gemma2Config, Gemma3Config, Gemma3TextConfig, Gemma3nConfig, Gemma3nTextConfig, GitConfig, GlmConfig, Glm4Config, Glm4MoeConfig, Glm4MoeLiteConfig, Glm4vConfig, Glm4vMoeConfig, GlmImageConfig, GlmAsrConfig, GotOcr2Config, GPT2Config, GPTBigCodeConfig, GPTNeoConfig, GPTNeoXConfig, GPTNeoXJapaneseConfig, GPTJConfig, GraniteConfig, GraniteMoeConfig, GraniteMoeHybridConfig, GraniteMoeSharedConfig, GroundingDinoConfig, GroupViTConfig, HubertConfig, IBertConfig, IdeficsConfig, Idefics2Config, InstructBlipConfig, InstructBlipVideoConfig, InternVLConfig, Jais2Config, JambaConfig, JanusConfig, JinaEmbeddingsV3Config, Kosmos2Config, LasrCTCConfig, LasrEncoderConfig, LayoutLMConfig, LayoutLMv2Config, LayoutLMv3Config, LayoutXLMConfig, LEDConfig, LightOnOcrConfig, LiltConfig, LlavaConfig, LlavaNextConfig, LongformerConfig, LukeConfig, LxmertConfig, M2M100Config, MambaConfig, Mamba2Config, MarianConfig, MarkupLMConfig, MBartConfig, MegatronBertConfig, MetaClip2Config, MgpstrConfig, MiniMaxM2Config, MinistralConfig, Ministral3Config, MistralConfig, Mistral3Config, MixtralConfig, MMGroundingDinoConfig, MobileBertConfig, ModernBertConfig, MPNetConfig, MptConfig, MraConfig, MT5Config, MusicgenConfig, MusicgenMelodyConfig, MvpConfig, NemotronConfig, NllbMoeConfig, NomicBertConfig, NougatConfig, NystromformerConfig, OlmoConfig, Olmo2Config, Olmo3Config, OlmoHybridConfig, OlmoeConfig, OmDetTurboConfig, OneFormerConfig, OpenAIGPTConfig, OPTConfig, Ovis2Config, Owlv2Config, OwlViTConfig, PegasusConfig, PegasusXConfig, PerceiverConfig, PhiConfig, Phi3Config, PhimoeConfig, Pix2StructConfig, PixtralVisionConfig, PLBartConfig, ProphetNetConfig, QianfanOCRConfig, Qwen2Config, Qwen2_5OmniConfig, Qwen2_5_VLConfig, Qwen2AudioConfig, Qwen2MoeConfig, Qwen2VLConfig, Qwen3Config, Qwen3_5Config, Qwen3_5MoeConfig, Qwen3MoeConfig, Qwen3NextConfig, Qwen3OmniMoeConfig, Qwen3VLConfig, Qwen3VLMoeConfig, RagConfig, RecurrentGemmaConfig, ReformerConfig, RemBertConfig, RobertaConfig, RobertaPreLayerNormConfig, RoCBertConfig, RoFormerConfig, RwkvConfig, Sam3Config, Sam3VideoConfig, SeamlessM4TConfig, SeamlessM4Tv2Config, ShieldGemma2Config, SiglipConfig, Siglip2Config, Speech2TextConfig, SpeechT5Config, SplinterConfig, SqueezeBertConfig, StableLmConfig, Starcoder2Config, SwitchTransformersConfig, T5Config, T5GemmaConfig, TapasConfig, TrOCRConfig, TvpConfig, UdopConfig, UMT5Config, UniSpeechConfig, UniSpeechSatConfig, ViltConfig, VipLlavaConfig, VisualBertConfig, VitsConfig, VoxtralConfig, VoxtralRealtimeConfig, Wav2Vec2Config, Wav2Vec2BertConfig, Wav2Vec2ConformerConfig, WhisperConfig, XCLIPConfig, XGLMConfig, XLMConfig, XLMRobertaConfig, XLMRobertaXLConfig, XLNetConfig, xLSTMConfig, XmodConfig, YosoConfig.

# %%
sentence = 'My name is Sarah. I live in London.'

# %%
translator(sentence, max_length=20)
